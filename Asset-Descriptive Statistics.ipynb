# %%
import pandas as pd
import statistics
import numpy as np

# Declaration
data = pd.read_csv("Kumande Asset - Food.csv")

target_col = ['calorie','Fat','sugar','Protein','Cholesterol','sodium','Water','Calcium','Nutrition Density']

for dt in target_col:
    # Convert to int
    data[dt] = pd.to_numeric(data[dt], errors='coerce')
    
    # Remove NaN
    data = data.dropna(subset=[dt])

    max_val = data[dt].max()
    min_val = data[dt].min()
    range_val = max_val - min_val
    mean = round(data[dt].mean(),2)
    mode = round(statistics.mode(data[dt]),2)
    var = round(np.nanvar(data[dt],ddof=1),2)
    std = round(var ** 0.5,2)

    print(f"Max of {dt.title()} : {max_val}")
    print(f"Min of {dt.title()} : {min_val}")
    print(f"Range of {dt.title()} : {range_val}")
    print(f"Mean of {dt.title()} : {mean}")
    print(f"Mode of {dt.title()} : {mode}")
    print(f"Variance of {dt.title()} : {var}")
    print(f"Standard Deviance of {dt.title()} : {std}\n")
# Out:
# Max of Calorie : 6077
# Min of Calorie : 0
# Range of Calorie : 6077
# Mean of Calorie : 223.77
# Mode of Calorie : 2
# Variance of Calorie : 148015.82
# Standard Deviance of Calorie : 384.73
#
# Max of Fat : 550.7
# Min of Fat : 0.0
# Range of Fat : 550.7
# Mean of Fat : 10.18
# Mode of Fat : 0.2
# Variance of Fat : 841.52
# Standard Deviance of Fat : 29.01
#
# Max of Sugar : 291.5
# Min of Sugar : 0.0
# Range of Sugar : 291.5
# Mean of Sugar : 4.46
# Mode of Sugar : 0.0
# Variance of Sugar : 177.95
# Standard Deviance of Sugar : 13.34
#
# Max of Protein : 560.3
# Min of Protein : 0.0
# Range of Protein : 560.3
# Mean of Protein : 13.4
# Mode of Protein : 0.0
# Variance of Protein : 1042.92
# Standard Deviance of Protein : 32.29
#
# Max of Cholesterol : 10509.0
# Min of Cholesterol : 0.0
# Range of Cholesterol : 10509.0
# Mean of Cholesterol : 62.17
# Mode of Cholesterol : 0.0
# Variance of Cholesterol : 148496.84
# Standard Deviance of Cholesterol : 385.35
#
# Max of Sodium : 49.4
# Min of Sodium : 0.0
# Range of Sodium : 49.4
# Mean of Sodium : 0.29
# Mode of Sodium : 0.2
# Variance of Sodium : 1.25
# Standard Deviance of Sodium : 1.12
#
# Max of Water : 1875.9
# Min of Water : 0.0
# Range of Water : 1875.9
# Mean of Water : 83.81
# Mode of Water : 0.0
# Variance of Water : 13717.36
# Standard Deviance of Water : 117.12
#
# Max of Calcium : 1283.5
# Min of Calcium : 0.0
# Range of Calcium : 1283.5
# Mean of Calcium : 52.05
# Mode of Calcium : 0.0
# Variance of Calcium : 13440.55
# Standard Deviance of Calcium : 115.93
#
# Max of Nutrition Density : 3911.4
# Min of Nutrition Density : 0.0
# Range of Nutrition Density : 3911.4
# Mean of Nutrition Density : 106.93
# Mode of Nutrition Density : 13.6
# Variance of Nutrition Density : 29937.27
# Standard Deviance of Nutrition Density : 173.02
