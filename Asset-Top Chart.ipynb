# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "Cal"
data = pd.read_csv("Kumande Asset - Food.csv")
msg = f"Top {limit} Foods by Calorie Count\n"

# Sorting
sorted_data = data.sort_values(by="calorie", ascending=False)
top = sorted_data[["food", "calorie"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, calorie) in enumerate(result):
    print(f"{idx + 1}. {food.title()} - {calorie} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result] 
total = [item[1] for item in result]  

# Bar Chart
plt.figure(figsize=(10, 6))
plt.bar(context, total, color="skyblue")

plt.title(msg.strip()) 
plt.xlabel("Food")
plt.ylabel(f"Calorie Count ({unit})")
plt.xticks(rotation=45) 

plt.tight_layout() 
plt.show()
# Out:
# Top 7 Foods by Calorie Count
#
# 1. Goose Meat Raw - 6077 Cal
# 2. Pork Arm Picnic Raw - 5298 Cal
# 3. Pork Arm Picnic Cooked - 5292 Cal
# 4. Duck Meat Raw - 5123 Cal
# 5. Pork Backfat - 3683 Cal
# 6. Pork Top Loin Roasts Raw - 3644 Cal
# 7. Pork Spareribs Raw - 3593 Cal

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "g"
data = pd.read_csv("Kumande Asset - Food.csv")
msg = f"Top {limit} Foods by Fat\n"

# Sorting 
sorted_data = data.sort_values(by="Fat", ascending=False)
top = sorted_data[["food","Fat"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, fat) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {fat} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context, total, color="skyblue")
plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Fat Count ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Fat
#
# 1. Goose Meat Raw - 550.7 g
# 2. Duck Meat Raw - 498.8 g
# 3. Pork Backfat - 402.3 g
# 4. Pork Arm Picnic Raw - 343.4 g
# 5. Pork Arm Picnic Cooked - 322.7 g
# 6. Pork Spareribs Raw - 303.5 g
# 7. Pork Belly Raw - 240.5 g

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "g"
data = pd.read_csv("Kumande Asset - Food.csv")
msg = f"Top {limit} Foods by Sugar\n"

# Sorting
sorted_data = data.sort_values(by="sugar", ascending=False)
top = sorted_data[["food","sugar"]].head(limit)
result = list(top.itertuples(index=False,name=None))

# List
print(msg)
for idx, (food, sugar) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {sugar} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total, color="skyblue")
plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Sugar Count ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Sugar
#
# 1. Vanilla Frosting - 291.5 g
# 2. Danone Low Fat Alsafi - 255.0 g
# 3. Banana Cream Pie - 143.0 g
# 4. Cranberry Sauce Sweetened - 105.0 g
# 5. Sweet Potato Canned - 98.3 g
# 6. Golden Raisins - 97.7 g
# 7. Zante Currants Dried - 96.9 g

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "g"
data = pd.read_csv("Kumande Asset - Food.csv")
msg = f"Top {limit} Foods by Protein\n"

# Sorting
sorted_data = data.sort_values(by="Protein",ascending=False)
top = sorted_data[["food","Protein"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, protein) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {protein} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total,color="skyblue")

plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Protein Count ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Protein
#
# 1. Pork Arm Picnic Cooked - 560.3 g
# 2. Pork Arm Picnic Raw - 513.6 g
# 3. Turkey Breast Roasted - 496.1 g
# 4. Turkey Breast Raw - 495.6 g
# 5. Pork Top Loin Roasts Raw - 468.4 g
# 6. Goose Meat Raw - 259.8 g
# 7. Pork Top Loin Roasts Roasted - 224.3 g

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "mg"
data = pd.read_csv("Kumande Asset - Food.csv")
msg = f"Top {limit} Foods by Cholesterol Count\n"

# Sorting
sorted_data = data.sort_values(by="Cholesterol", ascending=False)
top = sorted_data[["food","Cholesterol"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, Cholesterol) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {Cholesterol} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total,color="skyblue")

plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Cholesterol Count ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Cholesterol Count
#
# 1. Veal Brain Cooked - 10509.0 mg
# 2. Pork Brain Cooked - 9748.6 mg
# 3. Lamb Brain Cooked - 7089.2 mg
# 4. Beef Brain Cooked - 7002.5 mg
# 5. Pork Arm Picnic Cooked - 1936.7 mg
# 6. Pork Arm Picnic Raw - 1729.4 mg
# 7. Lamb Liver Cooked - 1683.4 mg

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "mg"
data = pd.read_csv("Kumande Asset - Food.csv")
msg = f"Top {limit} Foods by Sodium\n"

# Sorting
sorted_data = data.sort_values(by="sodium",ascending=False)
top = sorted_data[["food","sodium"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, sodium) in enumerate(result):
    print(f"{idx}. {food.title()} - {sodium} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total,color="skyblue")

plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Sodium Count ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Sodium
#
# 0. Adobo Fresco - 49.4 mg
# 1. Salt - 7.0 mg
# 2. Salt Mackerel - 6.1 mg
# 3. Jellyfish Dried - 5.6 mg
# 4. Corned Beef Raw - 5.5 mg
# 5. Pork Feet Pickled - 4.3 mg
# 6. Pork Blade Roll Roasted - 3.7 mg

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "mg"
msg = f"Top {limit} Foods by Calcium\n"
data = pd.read_csv("Kumande Asset - Food.csv")

# Sorting 
sorted_data = data.sort_values(by="Calcium",ascending=False)
top = sorted_data[["food","Calcium"]].head(limit)
result = list(top.itertuples(index=False,name=None))

# List 
print(msg)
for idx, (food, Calcium) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {Calcium} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total,color="skyblue")
plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Calcium Count ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Calcium
#
# 1. Mexican Cheese - 1283.5 mg
# 2. Sisymbrium Seeds - 1208.4 mg
# 3. Mozzarella Cheese Fat Free - 1085.9 mg
# 4. Provolone Cheese - 997.9 mg
# 5. Muenster Cheese - 946.4 mg
# 6. Salmon Canned - 918.8 mg
# 7. Chum Salmon Canned - 918.8 mg

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "per 100 Cal / Serving"
msg = f"Top {limit} Foods by Nutrition Density\n"
data = pd.read_csv("Kumande Asset - Food.csv")

# Sorting
sorted_data = data.sort_values(by="Nutrition Density", ascending=False)
top = sorted_data[["food","Nutrition Density"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, nutrition) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {nutrition} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total,color="skyblue")
plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Nutrition Density ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Nutrition Density
#
# 1. Acerola Cherry Juice - 3911.4 per 100 Cal / Serving
# 2. Banana Cream Pie - 1533.5 per 100 Cal / Serving
# 3. Mexican Cheese - 1337.0 per 100 Cal / Serving
# 4. Sisymbrium Seeds - 1286.643 per 100 Cal / Serving
# 5. Pork Arm Picnic Cooked - 1264.074 per 100 Cal / Serving
# 6. Pork Arm Picnic Raw - 1202.1 per 100 Cal / Serving
# 7. Mozzarella Cheese Fat Free - 1128.2 per 100 Cal / Serving

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Declaration
limit = 7
unit = "mg"
msg = f"Top {limit} Foods by Potassium\n"
data = pd.read_csv("Kumande Asset - Food.csv")

# Sorting
sorted_data = data.sort_values(by="Potassium", ascending=False)
top = sorted_data[["food","Potassium"]].head(limit)
result = list(top.itertuples(index=False, name=None))

# List
print(msg)
for idx, (food, Potassium) in enumerate(result):
    print(f"{idx+1}. {food.title()} - {Potassium} {unit}")
print("\n")

# Dataset
context = [item[0].title() for item in result]
total = [item[1] for item in result]

# Bar Chart
plt.figure(figsize=(10,6))
plt.bar(context,total,color="skyblue")
plt.title(msg.strip())
plt.xlabel("Food")
plt.ylabel(f"Potassium ({unit})")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top 7 Foods by Potassium
#
# 1. Pork Arm Picnic Raw - 11336.9 mg
# 2. Pork Arm Picnic Cooked - 8039.6 mg
# 3. Pork Top Loin Roasts Raw - 7858.1 mg
# 4. Turkey Breast Raw - 6226.0 mg
# 5. Goose Meat Raw - 5045.0 mg
# 6. Turkey Breast Roasted - 4976.6 mg
# 7. Oriental Radish Dried - 4053.0 mg
